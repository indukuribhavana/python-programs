# %% [markdown]
# <a href="https://colab.research.google.com/github/indukuribhavana/python-programs/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.bar(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([67,80,67,65,80,58,65,80,72])
b = (["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
plt.pie(y,labels=b)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

x = np.random.normal(170, 10, 250)


plt.hist(x)
plt.show()
