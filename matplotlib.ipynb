# %% [markdown]
# <a href="https://colab.research.google.com/github/indukuribhavana/python-programs/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#####BARS

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.bar(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.bar(x, y, color = "black")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.bar(x, y, width = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.barh(x, y, height = 2.0)
plt.show()

# %%
###PIECHARTS

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([67,80,67,65,80,58,65,80,72])
b = (["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
plt.pie(y,labels=b)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([67,80,67,65])
mylabels =  (["Chem","Clad","IT","C program"])
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([67,80,67,65])
mylabels =  (["Chem","Clad","IT","C program"])
mycolors = ["black", "hotpink", "red", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([67,80,67,65])
mylabels =  (["Chem","Clad","IT","C program"])

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
###HISTOGRAMS

# %%
import matplotlib.pyplot as plt
import numpy as np 

x = np.random.normal(67, 80, 67)


plt.hist(x)
plt.show()

# %%
####PYPLOT

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(xpoints, ypoints)
plt.show()

# %%
###PLOTTING

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["Chem","Clad","IT","C program","Eng","Single","Several","EVPR","VDC"])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])


plt.plot(xpoints, ypoints)
plt.show()

# %%
####MARKERS

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, 'o:b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'hotpink')
plt.show()

# %%
###LINE

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, ls = ':')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, color = 'g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(ypoints, c = 'hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([10, 15, 20, 25])
y2 = np.array([67,80,67,65])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([10, 15, 20, 25])
y1 = np.array([67,80,67,65])
x2 = np.array([30, 35, 40, 45])
y2 = np.array([80,58,65,80])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
###LABLES

# %%
import numpy as np
import matplotlib.pyplot as plt
 
x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
ypoints = np.array([67,80,67,65,80,58,65,80,72])
plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

font1 = {'family':'serif','color':'blue','size':30}
font2 = {'family':'serif','color':'darkred','size':20}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %%
####GRID

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
ypoints = np.array([67,80,67,65,80,58,65,80,72])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
ypoints = np.array([67,80,67,65,80,58,65,80,72])


plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
###SCATTER

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
y = np.array([67,80,67,65,80,58,65,80,72,89])

plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#sem1 marks for 9 subjects
x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50])
y = np.array([67,80,67,65,80,58,65,80,72])
plt.scatter(x, y)

#sem 1 marks for 10 subjects 
x = np.array([18, 46, 22, 27, 34, 35, 42, 43, 67, 60])
y = np.array([28,81,87,95,90,98,55,70,32,89])

plt.scatter(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50])
y = np.array([67,80,67,65,80,58,65,80,72])
plt.scatter(x, y, color = 'hotpink')

x = np.array([18, 46, 22, 27, 34, 35, 42, 43, 67, 60])
y = np.array([28,81,87,95,90,98,55,70,32,89])
plt.scatter(x, y, color = 'red')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50])
y = np.array([67,80,67,65,80,58,65,80,72])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","gray"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50])
y = np.array([67,80,67,65,80,58,65,80,72])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50])
y = np.array([67,80,67,65,80,58,65,80,72])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
####SUBPLOT

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([10, 1, 2, 5])
y = np.array([7,8,6,5])

plt.subplot(10, 5, 5)
plt.plot(x,y)

#plot 2:
x = np.array([8, 4, 2, 7])
y = np.array([1,5,9,8,])

plt.subplot(8, 7, 7)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([10, 1, 2, 5])
y = np.array([7,8,6,5])

plt.subplot(10, 5, 5)
plt.plot(x,y)

#plot 2:
x = np.array([8, 4, 2, 7])
y = np.array([1,5,9,8,])

plt.subplot(8, 7, 7)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([4, 5, 6, 7])
y = np.array([9, 8, 5, 2])

plt.subplot(4, 4, 5)
plt.plot(x,y)

x = np.array([8, 9, 10, 11])
y = np.array([8, 8, 1, 2])

plt.subplot(8, 11, 11)
plt.plot(x,y)

x = np.array([2, 4, 6, 8])
y = np.array([1, 2, 3, 4])

plt.subplot(2, 8, 8)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:


x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.title("OUTPUT")

#plot 2:
x = np.array([4, 5, 6, 7])
y = np.array([10, 20, 30, 40])

plt.subplot(4, 5, 5)
plt.plot(x,y)
plt.title("INPUT")

plt.show()
